# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading the CSV file
df=pd.read_csv('spotify-2023.csv',encoding='cp1252')
# Displaying first few rows in the dataset
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
# Dimension of dataset
print(f'Dimension of Dataset :\n{df.shape}')
# Out:
# Dimension of Dataset :
# (953, 24)

# %%
# Displaying the Information of Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
# Checking Null Values 
df.isna().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
# Summary Statistics
df.describe().transpose()
# Out:
#                       count         mean          std     min     25%     50%  \
# artist_count          953.0     1.556139     0.893044     1.0     1.0     1.0
# released_year         953.0  2018.238195    11.116218  1930.0  2020.0  2022.0
# released_month        953.0     6.033578     3.566435     1.0     3.0     6.0
# released_day          953.0    13.930745     9.201949     1.0     6.0    13.0
# in_spotify_playlists  953.0  5200.124869  7897.608990    31.0   875.0  2224.0
# in_spotify_charts     953.0    12.009444    19.575992     0.0     0.0     3.0
# in_apple_playlists    953.0    67.812172    86.441493     0.0    13.0    34.0
# in_apple_charts       953.0    51.908709    50.630241     0.0     7.0    38.0
# in_deezer_charts      953.0     2.666317     6.035599     0.0     0.0     0.0
# bpm                   953.0   122.540399    28.057802    65.0   100.0   121.0
# danceability_%        953.0    66.969570    14.630610    23.0    57.0    69.0
# ...

# %%
# Dropping 574 row because of it error value
df=df.drop(index=574)
# Dropping missing value column we dont want to filling inappropriate value in it
df=df.drop(labels=['in_shazam_charts','key'],axis=1)

# %%
df['in_deezer_playlists']=df['in_deezer_playlists'].str.replace(',','')
df['in_deezer_playlists']=pd.to_numeric(df['in_deezer_playlists'])
df['streams']=pd.to_numeric(df['streams'])

# %%
df['released_date']=pd.to_datetime(df['released_day'].astype('str')+"-"+df['released_month'].astype('str')+"-"+df['released_year'].astype('str'))
df['released_date']
# Out:
# 0     2023-07-14
# 1     2023-03-23
# 2     2023-06-30
# 3     2019-08-23
# 4     2023-05-18
#          ...
# 948   2022-03-11
# 949   2022-10-21
# 950   2022-03-11
# 951   2022-10-20
# 952   2022-04-11
# Name: released_date, Length: 952, dtype: datetime64[ns]

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),cmap='inferno',linewidths=1,linecolor='black',annot=True)
plt.show()

# %%
# Top 10 songs on spotify
top_10_songs=df.sort_values(by='streams',ascending=False).head(10)

# %%
# Visualizing top 10 most stream song on spotify
plt.figure(figsize=(20,10))
sns.barplot(x='track_name',y='streams',data=top_10_songs)
plt.title('Top 10 Most Streamed Song on Spotify')
plt.xlabel('Track Name')
plt.xticks(rotation=65)
plt.ylabel('Streams')
plt.show()

# %%
# Top 10 most streams songs of 2023
top_10_2023=df[df['released_year']==2023].sort_values(by='streams',ascending=False).head(10)

# %%
# Visualizing top 10 song of 2023
plt.figure(figsize=(20,10))
sns.barplot(x='track_name',y='streams',data=top_10_2023)
plt.title('Top 10 Most Streamed Song on Spotify in 2023')
plt.xlabel('Track Name')
plt.xticks(rotation=65)
plt.ylabel('Streams')
plt.show()

# %%
# Group the data by artist name and sum the streams for each artist
artist_streams=df.groupby('artist(s)_name')['streams'].sum().reset_index()

# Sort the DataFrame by the total streams in descending order
top_10_artist=artist_streams.sort_values(by='streams',ascending=False).head(10)

# Display the top 10 artists
top_10_artist
# Out:
#       artist(s)_name      streams
# 571       The Weeknd  14185552870
# 557     Taylor Swift  14053658300
# 159       Ed Sheeran  13908947204
# 222     Harry Styles  11608645649
# 43         Bad Bunny   9997799607
# 430   Olivia Rodrigo   7442148916
# 170           Eminem   6183805596
# 75        Bruno Mars   5846920599
# 25    Arctic Monkeys   5569806731
# 228  Imagine Dragons   5272484650

# %%
# Visualizing top 10 most streams artist on apotify
plt.figure(figsize=(20,10))
sns.barplot(x='artist(s)_name',y='streams',data=top_10_artist)
plt.title('Top 10 Most Streamed Artist on Spotify')
plt.xlabel('Artist Name')
plt.xticks(rotation=65)
plt.ylabel('Streams')
plt.show()

# %%
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
playlist_song=df.groupby('track_name')['in_spotify_playlists'].max().reset_index()
top_10_added_song = playlist_song.sort_values(by='in_spotify_playlists',ascending=False).head(10)
top_10_added_song
# Out:
#                                     track_name  in_spotify_playlists
# 296                     Get Lucky - Radio Edit                 52898
# 516                             Mr. Brightside                 51979
# 866                    Wake Me Up - Radio Edit                 50887
# 711  Smells Like Teen Spirit - Remastered 2021                 49991
# 783                                 Take On Me                 44927
# 100                            Blinding Lights                 43899
# 562                                  One Dance                 43257
# 721               Somebody That I Used To Know                 42798
# 256          Everybody Wants To Rule The World                 41751
# 763                        Sweet Child O' Mine                 41231

# %%
plt.figure(figsize=(20,10))
sns.barplot(y='track_name',x='in_spotify_playlists',data=top_10_added_song,orient='h')
plt.title('Most Added Song on Spotify Playlist')
plt.ylabel('Track Name')
plt.xlabel('Count of Song Added')
plt.show()

# %%
apple_playlist=df.groupby('track_name')['in_apple_playlists'].max().reset_index()
top_10_apple=apple_playlist.sort_values(by='in_apple_playlists',ascending=False).head(10)
top_10_apple
# Out:
#                     track_name  in_apple_playlists
# 100            Blinding Lights                 672
# 563   One Kiss (with Dua Lipa)                 537
# 184               Dance Monkey                 533
# 212            Don't Start Now                 532
# 661  STAY (with Justin Bieber)                 492
# 688                  Seï¿½ï¿½o                 453
# 722          Someone You Loved                 440
# 868           Watermelon Sugar                 437
# 562                  One Dance                 433
# 60                   As It Was                 403

# %%
plt.figure(figsize=(20,10))
sns.barplot(y='track_name',x='in_apple_playlists',data=top_10_apple,orient='h')
plt.title('Most Added Song In Apple Playlist')
plt.xlabel('Count of Song Added')
plt.ylabel('Track Name')
plt.show()

# %%
deezer_playlist=df.groupby('track_name')['in_deezer_playlists'].max().reset_index()
top_10_deezer=deezer_playlist.sort_values(by='in_deezer_playlists',ascending=False).head(10)
top_10_deezer
# Out:
#                                     track_name  in_deezer_playlists
# 711  Smells Like Teen Spirit - Remastered 2021                12367
# 296                     Get Lucky - Radio Edit                 8215
# 810                              The Scientist                 7827
# 549                                       Numb                 7341
# 364                                 In The End                 6808
# 692                               Shape of You                 6808
# 167                                      Creep                 6807
# 763                        Sweet Child O' Mine                 6720
# 744                               Still D.R.E.                 6591
# 132           Can't Hold Us (feat. Ray Dalton)                 6551

# %%
plt.figure(figsize=(20,10))
sns.barplot(y='track_name',x='in_deezer_playlists',data=top_10_deezer,orient='h')
plt.title('Most Added Song In Deezer Playlist')
plt.xlabel('Count of Song Added')
plt.ylabel('Track Name')
plt.show()
