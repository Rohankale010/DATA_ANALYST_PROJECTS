# %%
import pandas as pd
from mlxtend.frequent_patterns import fpgrowth,association_rules
import warnings
warnings.filterwarnings(action='ignore')

# %%
filepath='D:\Projects\DATA_ANALYST_PROJECTS\Customer_Segmentation_&_Market_Basket_Analysis\data\Market_Basket_Processed.csv'
basket=pd.read_csv(filepath,index_col=0)

# %%
basket.head()
# Out:
#         10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# BillNo
# 536365                       0                           0
# 536366                       0                           0
# 536367                       0                           0
# 536368                       0                           0
# 536369                       0                           0
#
#         12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# BillNo
# 536365                          0                          0
# 536366                          0                          0
# 536367                          0                          0
# 536368                          0                          0
# 536369                          0                          0
#
#         12 HANGING EGGS HAND PAINTED  12 IVORY ROSE PEG PLACE SETTINGS  \
# BillNo
# 536365                             0                                 0
# ...

# %%
# Apply Fp-Growth Algorithm
frequent_itemset=fpgrowth(basket,min_support=0.01,use_colnames=True)

# %%
# Generate Association Rules
rules=association_rules(frequent_itemset,metric='lift',min_threshold=1.0)

# %%
# Filter Important Rules (Strong Rules with high confidence & lift)
rules=rules[(rules['confidence']>=0.2)&(rules['lift']>=1.2)]

# %%
rules=rules.sort_values(by=['lift','confidence'],ascending=False)

# %%
rules.to_csv('D:\Projects\DATA_ANALYST_PROJECTS\Customer_Segmentation_&_Market_Basket_Analysis\data/Market_Basket_Rules.csv',index=False)

# %%
rules.head()
# Out:
#                         antecedents                  consequents  \
# 893      (REGENCY SUGAR BOWL GREEN)      (REGENCY MILK JUG PINK)
# 892         (REGENCY MILK JUG PINK)   (REGENCY SUGAR BOWL GREEN)
# 891       (REGENCY TEA PLATE GREEN)    (REGENCY TEA PLATE ROSES)
# 890       (REGENCY TEA PLATE ROSES)    (REGENCY TEA PLATE GREEN)
# 599  (POPPY'S PLAYHOUSE LIVINGROOM)  (POPPY'S PLAYHOUSE BEDROOM)
#
#      antecedent support  consequent support   support  confidence       lift  \
# 893            0.013269            0.013489  0.010130    0.763485  56.600762
# 892            0.013489            0.013269  0.010130    0.751020  56.600762
# 891            0.013544            0.016572  0.011397    0.841463  50.775748
# 890            0.016572            0.013544  0.011397    0.687708  50.775748
# 599            0.013434            0.016902  0.010901    0.811475  48.009211
#
#      leverage  conviction  zhangs_metric
# 893  0.009952    4.171038       0.995542
# ...
